# %% [markdown]
# 1. Given a string of odd length greater than 7, return a new string made of the middle three characters
# of a given String
# Given:
# str1 = "RakeshzipPetabb"
# Output
# zip
# str2 = "JazzbonAyxx"
# Output
# bon

# %%
str1 = "RakeshzipPetabb"
mid= len(str1)//2

str1 = str1[mid-1:mid+2:]
print(str1)
# Out:
# zip

# %% [markdown]
# 2. Given two strings, s1 and s2, create a new string by appending s2 in the middle of s1
# Given:
# s1 = "Ault"
# s2 = "Kelly"
# Expected Output:
# AuKellylt

# %%
s1 = "Ault"
s2 = "Kelly"
s1=[*s1]

mid=len(s1)//2
# s1= s1.append(mid,s2)
s1.insert(mid,s2)

print("".join(s1))
# Out:
# AuKellylt

# %% [markdown]
# 3. two strings, s1, and s2 return a new string made of the first, middle, and last characters each input
# string
# Given:
# s1 = "America"
# s2 = "Japan"
# Expected Output:
# AJrpan

# %%
s1 = "America"
s2 = "Japan"
s1=[*s1]
s2=[*s2]
mids1=len(s1)//2
mids2=len(s2)//2

print(s1[0],s2[0],s1[mids1],s2[mids2],s1[-1],s2[-1],sep='')
# Out:
# AJrpan

# %% [markdown]
# 4. Given an input string with the combination of the lower and upper case arrange characters in such a
# way that all lowercase letters should come first.

# %%
n=input("Enter a string: ")
l1, l2=[],[]

for ele in n:
  a=ele.islower()
  if (ele.islower()):
    l1.append(ele)
  elif ele.isupper():
    l2.append(ele)

l1.extend(l2)
print(''.join(l1))
# Out:
# Enter a string: jfifiuhHUSDsdufsiHUuhHUhiuuFrt
# jfifiuhsdufsiuhhiuurtHUSDHUHUF

# %% [markdown]
# 5. create a third-string made of the first char of s1 then the last char of s2, Next, the second char of s1
# and second last char of s2, and so on. Any leftover chars go at the end of the result.
# Given:
# s1 = "Abc"
# s2 = "Xyz"
# Expected Output:
# AzbycX

# %%
s1,s2 = "Abc", "Xyz"
s1=[*s1]
s2=[*s2][::-1] # s2=[*s2] then reverse it

for ele1, ele2 in zip(s1,s2):
  print(ele1, ele2, sep="",end="")
# Out:
# AzbycX

# %% [markdown]
# 6. Find all occurrences of “USA” from right to left in a given string ignoring the case. also display the
# starting position
# Given:
# str1 = "Welcome to USA. usa awesome, isn't it?
# Expected answer : 16, 11

# %%
str1 = "Welcome to USA. usa awesome, isn't it?"

for i in range(len(str1)):
  a=str1[i:i+3:]
  if (a=="USA") or (a=="usa"):
    print(i, end=' ')
# Out:
# 11 16

# %%
str1 = "Welcome to USA. usa awesome, isn't it?"

for i in range(len(str1)):
  a=str1.rfind("USA", i)
  b=str1.rfind("usa", i)
  if (a>0) or (b>0):
    print(b, a)
    break
# Out:
# 16 11

# %% [markdown]
# 7. Find all overlapping occurrences of given substring in given string
# Ex.
# String = 0111
# Substring = 11
# Expected answer : 2
# String : ANANAAAANNN
# Substring: ANA
# Expected answer : 2
# String : ANANAAAANNN
# Substring: AA
# Expected answer : 3

# %%
s="ANANAAAANNN"
sub_s="ANA"
count=0

for i in range(0,len(s)):
  a=s[i:i+len(sub_s):]
  if a==sub_s:
    count+=1
print(count)
# Out:
# 2

# %% [markdown]
# 8. Given a string in format Emp_name:Emp_id
# If emp_is is perfect square -- > Print only vowels from emp_name
# Else if emp_id is prime -- > print alternate characters from emp_name
# Else if emp_id is odd -- > print sum of ascii values of characters in emp_name
# Else print None

# %%
import math
import sympy
emp_name = "Ganesh"
emp_id= 15
id= math.sqrt(emp_id)
vowel= ['a','e','i','o','u','A','E','I','O','U']
name_vowel=""
if id.is_integer():             #emp_is is perfect square
  for i in vowel:
    if i in emp_name:
      name_vowel= name_vowel+i
  print(name_vowel)
elif sympy.isprime(emp_id):     #emp_id is prime
  print(emp_name[::2])
elif emp_id%2!=0:               #emp_id is odd
  for i in emp_name:
    sum=+ord(i)                 #ord function used to get ASCII Value
  print("Sum of ASCII valuse is : ",sum)
else:
  print("None")
# Out:
# Sum of ASCII valuse is :  104

# %% [markdown]
# 9. Find all mobile number mentioned in given paragraph of text
# Mobile number is always a 10 digit number no spaces no special characters
# Ex. Input= “this is a good number 9089786756 and 8900000000 is a desired number”
# Expected output: 9089786756 , 8900000000

# %%
n= "this is a good number 9089786756 and 8900000000 is a desired number"

for i in range(len(n)):
  a=n[i:i+10:]
  if a.isdigit():
    print(a)
# Out:
# 9089786756
# 8900000000

# %% [markdown]
# 10. Count occurrence of spaces, and special characters in given string
# Ex.
# Input: Fgh^f #89
# Expected output :
# Spaces: 1
# Special characters: 2

# %%
n="Fgh^f #89"
sp_char="!@#$%^&*()_+<>?:|[{,./\';}]"
count=0
space=0
for i in n:
  if i==" ":
    space+=1
  elif (i in sp_char):
    count+=1
print("Spaces : ", space,"\nSpecial characters: ",count)
# Out:
# ^
# #
# Spaces :  1
# Special characters:  2

# %% [markdown]
# 11. Given a paragraph count number of words, sentences. Every sentence ends with either . or ? or !
# Print Count of how many normal sentences ending with . , how many interrogative sentences ( ending
# with ?) and how many exclamatory sentences ( ending with !).
# Ex.
# Input : “I am at CDAC. What about you? I am surprised by current weather!”
# Normal sentence : 1
# Interrogative: 1
# Exclamatory : 1

# %%
n="I am at CDAC. What about you? I am surprised by current weather!"
ncount=0
scount=0
ecount=0
for i in n:
  if i==".":
    ncount=+1
  elif i==" ":
    scount=+1
  elif i=="?":
    ecount=+1
print("Normal sentence : ", ncount)
print("Interrogative: ", scount)
print("Exclamatory: ",ecount)
# Out:
# Normal sentence :  1
# Interrogative:  1
# Exclamatory:  1

# %% [markdown]
# 12. You are given a string S and width w.
# Your task is to wrap the string into a paragraph of width w
# Example .
# String : “ABCDEFGHIJKLIMNOQRSTUVWXYZ”
# Width: 4
# Output:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ

# %%
n="ABCDEFGHIJKLIMNOQRSTUVWXYZ"
for i in range(0,len(n),4):
  a=n[i:i+4:1]
  print(a)
# Out:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ
